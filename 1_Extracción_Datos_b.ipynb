# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/Extracci-n-Datos/blob/main/1_Extracci%C3%B3n_Datos_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv o xlsx desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_excel('Datos de Facturación.xlsx')
#df

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10890 non-null  object
#  1   CVE_CLPV       10895 non-null  object
#  2   STATUS         10886 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10893 non-null  datetime64[ns]
#  5   FECHA_DOC      10894 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10889 non-null  float64
#  10  DES_TOT        10894 non-null  float64
#  11  DES_FIN        10892 non-null  float64
# dtypes: datetime64[ns](4), float64(4), object(4)
# memory usage: 1021.5+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
df.head()
# Out:
#   CVE_DOC    CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414        2465      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415        3926      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416        3926      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417        3926      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418        6813      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04  3980.00      0.0      0.0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 3  2019-09-03 00:00:00 2019-10-03    2019-09-17  1550.00      0.0      0.0
# 4  2019-09-03 00:00:00 2019-09-03    2019-09-10  2435.44      0.0      0.0

# %%
#Conversión de tipo de dato de columna de tipo Object a Float
df['CVE_CLPV']= df['CVE_CLPV'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d66938463dbd> in <cell line: 2>()
#       1 #Conversión de tipo de dato de columna de tipo Object a Float
# ----> 2 df['CVE_CLPV']= df['CVE_CLPV'].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# --> 414         return self.apply(
#     415             "astype",
# ...

# %%
#Reemplazo de datos tipo string a datos tipo numérico
df.CVE_CLPV = df.CVE_CLPV.replace({'6781|':'6781'}, regex=False)

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto
filtro1=df[df["FECHA_VENCIMIENTO"] == "2023-04-13"]
filtro1

# %%
#Filtro por filas
filtro2= df.iloc[8:15 , : ]           #Filas consecutivas
#filtro2=df.iloc[ [8, 24, 100] , : ]  #Filas no consecutivas
filtro2

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 1:3]       #Columnas consecutivas
filtro3=df.iloc[ : , [1,4,5]]  #Columnas no consecutivas
filtro3

# %%
df1= pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx', index_col=1)
df1

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["HELVEX","DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO"]]
filtro4

# %%
#Filtro por cabecera
filtro5=df.tail()
filtro5

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
filtro6=df[df["MONTO ADEUDADO"] <= 100]
filtro6
# Out:
#     No. CLIENTE                                             NOMBRE  FACTURA  \
# 158        8698                               OLMO RACKS & DUNNAGE      NaN
# 159         856  CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADO...   F40055
# 160        5926                                 PÚBLICO EN GENERAL  NV00777
# 161        5926                                 PÚBLICO EN GENERAL  NV00778
# 162        5926                                 PÚBLICO EN GENERAL  NV00779
# 163        8429                                  FISHERS QUERETARO   F38248
#
#     FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 158    2022-06-28        2022-06-28           87.35
# 159    2023-01-31        2023-01-31           56.00
# 160    2023-03-07        2023-03-07           45.00
# 161    2023-03-09        2023-03-09           40.00
# 162    2023-03-09        2023-03-09           24.01
# 163    2022-05-27        2022-05-27           19.94

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
filtro7=df[(df["MONTO ADEUDADO"] < 6000) & (df["FECHA_FACTURA"] == "2023-03-14")]
filtro7

# %%
#Filtro o
filtro8=df[(df["MONTO ADEUDADO"] < 6000) | (df["FECHA_FACTURA"] == "2023-03-14")]
filtro8

# %%
#Filtro not
filtro9=df[~(df["FECHA_FACTURA"] == "2023-03-14")]
filtro9

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Filtro1.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files


files.download("Filtro1.csv")
